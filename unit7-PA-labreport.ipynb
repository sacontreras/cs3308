# %% [markdown]
# # Part 1: Webcrawler: Inverted Index creation

# %%
from unit7.webcrawler_indexer import WebCrawlInvertedIndexer
from unit4.indexer_storage import SQLiteInvertedIndexStorage
from common import disp

# %load_ext autoreload
# %autoreload 2

# %%
b_quit = False
b_first_run = True # use this to purge the on the first run and append to it thereafter
while not b_quit:
    root_url = input("Enter URL to crawl (must be in the form http://www.domain.com): ").strip()
    if len(root_url) == 0:
        b_quit = len(input("Are you sure you want to QUIT? (press ENTER again to confirm): ").strip()) == 0
    else:
        WebCrawlInvertedIndexer(
            storage=SQLiteInvertedIndexStorage(root_dir="./unit7", db_fname="webcrawler.db"),
            max_n_outlinks=500
        ).reindex_url(root_url, overwrite_storage=b_first_run)
    b_first_run = False
# Out:
# Enter URL to crawl (must be in the form http://www.domain.com):  https://cnn.com
# Start Time: 17:39
#
# URLs queued: 0, INDEXING CURRENT URL: https://cnn.com...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='', params='', query='', fragment='')
# 	html doc contains 247 outlinks
# 		queueing link: https://cnn.com/us
# 		queueing link: https://cnn.com/world
# 		queueing link: https://cnn.com/politics
# 		queueing link: https://cnn.com/business
# 		queueing link: https://cnn.com/opinions
# 		queueing link: https://cnn.com/health
# 		queueing link: https://cnn.com/entertainment
# 		queueing link: https://cnn.com/style
# 		queueing link: https://cnn.com/travel
# 		queueing link: http://bleacherreport.com
# 		queueing link: https://cnn.com/videos
# 		queueing link: https://us.cnn.com?hpt=header_edition-picker
# 		queueing link: https://edition.cnn.com?hpt=header_edition-picker
# 		queueing link: https://arabic.cnn.com?hpt=header_edition-picker
# 		queueing link: https://cnnespanol.cnn.com?hpt=header_edition-picker
# 		queueing link: https://cnn.com/specials/us/crime-and-justice
# 		queueing link: https://cnn.com/specials/us/energy-and-environment
# 		queueing link: https://cnn.com/specials/us/extreme-weather
# 		queueing link: https://cnn.com/specials/space-science
# 		queueing link: https://cnn.com/africa
# 		queueing link: https://cnn.com/americas
# 		queueing link: https://cnn.com/asia
# 		queueing link: https://cnn.com/australia
# 		queueing link: https://cnn.com/china
# 		queueing link: https://cnn.com/europe
# 		queueing link: https://cnn.com/india
# 		queueing link: https://cnn.com/middle-east
# 		queueing link: https://cnn.com/uk
# 		queueing link: https://cnn.com/election/2020
# 		queueing link: https://cnn.com/specials/politics/president-donald-trump-45
# 		queueing link: https://cnn.com/specials/politics/supreme-court-nine
# 		queueing link: https://cnn.com/specials/politics/congress
# 		queueing link: https://cnn.com/specials/politics/fact-check-politics
# 		queueing link: https://money.cnn.com/data/markets/
# 		queueing link: https://cnn.com/business/tech
# 		queueing link: https://cnn.com/business/media
# 		queueing link: https://cnn.com/business/success
# 		queueing link: https://cnn.com/business/perspectives
# 		queueing link: https://cnn.com/business/videos
# 		queueing link: https://cnn.com/specials/opinion/opinion-politics
# 		queueing link: https://cnn.com/specials/opinion/opinion-social-issues
# 		queueing link: https://cnn.com/specials/health/food-diet
# 		queueing link: https://cnn.com/specials/health/fitness-excercise
# 		queueing link: https://cnn.com/specials/health/wellness
# 		queueing link: https://cnn.com/specials/health/parenting
# 		queueing link: https://cnn.com/specials/health/vital-signs
# 		queueing link: https://cnn.com/entertainment/celebrities
# 		queueing link: https://cnn.com/entertainment/movies
# 		queueing link: https://cnn.com/entertainment/tv-shows
# 		queueing link: https://cnn.com/entertainment/culture
# 		queueing link: https://cnn.com/specials/tech/innovate
# 		queueing link: https://cnn.com/specials/tech/gadget
# 		queueing link: https://cnn.com/specials/tech/foreseeable-future
# 		queueing link: https://cnn.com/specials/tech/mission-ahead
# 		queueing link: https://cnn.com/specials/tech/upstarts
# 		queueing link: https://cnn.com/specials/tech/work-transformed
# 		queueing link: https://cnn.com/specials/tech/innovative-cities
# 		queueing link: https://cnn.com/style/arts
# 		queueing link: https://cnn.com/style/design
# 		queueing link: https://cnn.com/style/fashion
# 		queueing link: https://cnn.com/style/architecture
# 		queueing link: https://cnn.com/style/luxury
# 		queueing link: https://cnn.com/style/beauty
# 		queueing link: https://cnn.com/style/videos
# 		queueing link: https://cnn.com/travel/destinations
# 		queueing link: https://cnn.com/travel/food-and-drink
# 		queueing link: https://cnn.com/travel/stay
# 		queueing link: https://cnn.com/travel/news
# 		queueing link: https://cnn.com/travel/videos
# 		queueing link: http://bleacherreport.com/nfl
# 		queueing link: http://bleacherreport.com/college-football
# 		queueing link: http://bleacherreport.com/nba
# 		queueing link: http://bleacherreport.com/mlb
# 		queueing link: http://bleacherreport.com/world-football
# 		queueing link: https://cnn.com/specials/sport/winter-olympics-2018
# 		queueing link: https://cnn.it/go2
# 		queueing link: https://cnn.com/specials/digital-studios
# 		queueing link: https://cnn.com/specials/videos/digital-shorts
# 		queueing link: https://cnn.com/specials/videos/hln
# 		queueing link: https://cnn.com/tv/schedule/cnn
# 		queueing link: https://cnn.com/specials/tv/all-shows
# 		queueing link: https://cnn.com/vr
# 		queueing link: https://coupons.cnn.com
# 		queueing link: https://cnn.com/cnn-underscored/
# 		queueing link: https://cnn.com/specials/cnn-underscored/explore/
# 		queueing link: https://cnn.com/specials/cnn-underscored/wellness/
# 		queueing link: https://cnn.com/specials/cnn-underscored/gadgets/
# 		queueing link: https://cnn.com/specials/cnn-underscored/lifestyle/
# 		queueing link: https://store.cnn.com/?utm_source=cnn.com&amp;utm_medium=referral&amp;utm_campaign=navbar
# 		queueing link: https://cnn.com/more
# 		queueing link: https://cnn.com/specials/photos
# 		queueing link: https://cnn.com/specials/cnn-longform
# 		queueing link: https://cnn.com/specials/cnn-investigates
# 		queueing link: https://cnn.com/specials/profiles
# 		queueing link: https://cnn.com/specials/more/cnn-leadership
# 		queueing link: https://cnn.com/email/subscription
# 		queueing link: https://www.turnerjobs.com/search-jobs?orgIds=1174&amp;ac=19299
# 		queueing link: https://cnn.com/weather
# 		queueing link: https://cnn.com/specials/world/cnn-climate
# 		queueing link: https://cnn.com/interactive/2020/weather/gonzalo-storm-path-tracker/index.html
# 		queueing link: https://cnn.com/specials/weather/weather-video
# 		queueing link: https://facebook.com/CNN
# 		queueing link: https://twitter.com/CNN
# 		queueing link: https://instagram.com/cnn
# 		queueing link: https://www.cnn.com/terms
# 		queueing link: https://www.cnn.com/privacy
# 		queueing link: https://www.warnermediaprivacy.com/affiliates/
# 		queueing link: https://turneraffiliates.turner.com/Affiliates/Turner-Affiliates-English
# 		queueing link: mailto:WMPrivacy@warnermediagroup.com
# 		queueing link: https://cnn.com/terms
# 		queueing link: https://cnn.com/privacy
# 		queueing link: https://cnn.com/accessibility
# 		queueing link: https://cnn.com/about
# 		queueing link: https://cnn.com/tour
# 		queueing link: https://store.cnn.com
# 		queueing link: https://cnn.com/newsletters
# 		queueing link: https://cnn.com/transcripts
# 		queueing link: https://cnn.com/collection
# 		queueing link: http://cnnnewsource.com
# 		queueing link: https://www.cnn.com/sitemap.html
# 		queueing link: https://www.turner.com
# 		queueing link: https://cdn.cnn.com/cnn/.e/img/3.0/global/misc/cnn-logo.png
# 		*** 125 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 120, INDEXING CURRENT URL: https://www.turner.com...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='www.turner.com', path='', params='', query='', fragment='')
# 	html doc contains 58 outlinks
# 		queueing link: https://www.turner.com#main-content
# 		queueing link: https://www.turner.com/company
# 		queueing link: https://investors.att.com/
# 		queueing link: https://www.turner.com/newsroom
# 		queueing link: https://www.warnermediacareers.com/
# 		queueing link: https://www.turner.com/about-us
# 		queueing link: https://www.turner.com/leadership-team
# 		queueing link: https://www.turner.com/company/business-units
# 		queueing link: https://www.turner.com/company/corporate-responsibility
# 		queueing link: https://www.turner.com/company/strategy
# 		queueing link: https://www.turner.com/press-contacts
# 		queueing link: https://www.turner.com/media-and-identity-materials
# 		queueing link: https://www.turner.com/working-us
# 		queueing link: https://www.facebook.com/warnermedia/
# 		queueing link: https://twitter.com/WarnerMedia
# 		queueing link: https://www.youtube.com/c/WarnerMedia
# 		queueing link: https://www.instagram.com/warnermedia/
# 		queueing link: https://www.cnncreativemarketing.com/project/usoa/
# 		queueing link: https://www.dccomics.com/dcfandome
# 		queueing link: https://www.hbomax.com/index.html
# 		queueing link: https://www.hbomax.com/
# 		queueing link: https://www.warnermediagroup.com/empathy-understanding-and-action-how-were-confronting-racial-injustice
# 		queueing link: https://www.warnermediagroup.com/covid-19-how-warnermedia-helping
# 		queueing link: https://www.tntdrama.com/angel-of-darkness
# 		queueing link: https://www.warnermediagroup.com/what-warnermedia-doing-response-covid-19
# 		queueing link: https://www.cnn.com/audio/podcasts/corona-virus
# 		queueing link: https://www.tntdrama.com/nba-on-tnt?cid=Digital-Portfolio_NBA-on-TNT-Restart_2020_WarnerMedia&amp;source=Digital-Portfolio&amp;campaign=NBA-on-TNT-Restart_2020_WarnerMedia
# 		queueing link: https://trutv.app.link/HAfoCcmap4?%243p=a_custom_761352279751481230
# 		queueing link: http://warnermediadiversity.com
# 		queueing link: https://www.turner.com/legal-and-privacy
# 		queueing link: https://www.turner.com/ethics-and-compliance
# 		queueing link: https://www.turner.com/contact-us
# 		queueing link: https://www.turner.com/shop
# 		queueing link: https://www.turner.com/sitemap
# 		*** 24 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 153, INDEXING CURRENT URL: https://www.turner.com/sitemap...
# 	cannot index this document due to exception: HTTP Error 404: Not Found
# URLs queued: 152, INDEXING CURRENT URL: https://www.turner.com/shop...
# 	cannot index this document due to exception: HTTP Error 404: Not Found
# URLs queued: 151, INDEXING CURRENT URL: https://www.turner.com/contact-us...
# 	cannot index this document due to exception: HTTP Error 404: Not Found
# URLs queued: 150, INDEXING CURRENT URL: https://www.turner.com/ethics-and-compliance...
# 	cannot index this document due to exception: HTTP Error 404: Not Found
# URLs queued: 149, INDEXING CURRENT URL: https://www.turner.com/legal-and-privacy...
# 	cannot index this document due to exception: HTTP Error 404: Not Found
# URLs queued: 148, INDEXING CURRENT URL: http://warnermediadiversity.com...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		queueing link: http://warnermediadiversity.com#main-content
# 		queueing link: http://warnermediadiversity.com/company
# 		queueing link: http://warnermediadiversity.com/newsroom
# 		queueing link: http://warnermediadiversity.com/about-us
# 		queueing link: http://warnermediadiversity.com/leadership-team
# 		queueing link: http://warnermediadiversity.com/company/business-units
# 		queueing link: http://warnermediadiversity.com/company/corporate-responsibility
# 		queueing link: http://warnermediadiversity.com/company/strategy
# 		queueing link: http://warnermediadiversity.com/press-contacts
# 		queueing link: http://warnermediadiversity.com/media-and-identity-materials
# 		queueing link: http://warnermediadiversity.com/working-us
# 		queueing link: https://mss-wmg-prd.s3.amazonaws.com/WarnerMedia_D%26I_Report_2019_FINAL_V2.pdf
# 		queueing link: mailto:?subject=WarnerMedia%20Diversity%20and%20Inclusion%20Interim%20Report&amp;body=https://mss-wmg-prd.s3.amazonaws.com/WarnerMedia_D%26I_Report_2019_FINAL_V2.pdf
# 		queueing link: http://warnermediadiversity.com/legal-and-privacy
# 		queueing link: http://warnermediadiversity.com/ethics-and-compliance
# 		queueing link: http://warnermediadiversity.com/contact-us
# 		queueing link: http://warnermediadiversity.com/shop
# 		queueing link: http://warnermediadiversity.com/sitemap
# 		*** 12 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 165, INDEXING CURRENT URL: http://warnermediadiversity.com/sitemap...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/sitemap', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		queueing link: http://warnermediadiversity.com/sitemap
# 		*** 29 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 165, INDEXING CURRENT URL: http://warnermediadiversity.com/sitemap...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/sitemap', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		*** 30 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 164, INDEXING CURRENT URL: http://warnermediadiversity.com/shop...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/shop', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		queueing link: http://warnermediadiversity.com/shop
# 		*** 29 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 164, INDEXING CURRENT URL: http://warnermediadiversity.com/shop...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/shop', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		*** 30 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 163, INDEXING CURRENT URL: http://warnermediadiversity.com/contact-us...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/contact-us', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		queueing link: http://warnermediadiversity.com/contact-us
# 		*** 29 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 163, INDEXING CURRENT URL: http://warnermediadiversity.com/contact-us...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/contact-us', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		*** 30 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 162, INDEXING CURRENT URL: http://warnermediadiversity.com/ethics-and-compliance...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/ethics-and-compliance', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		queueing link: http://warnermediadiversity.com/ethics-and-compliance
# 		*** 29 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 162, INDEXING CURRENT URL: http://warnermediadiversity.com/ethics-and-compliance...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/ethics-and-compliance', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		*** 30 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 161, INDEXING CURRENT URL: http://warnermediadiversity.com/legal-and-privacy...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/legal-and-privacy', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		queueing link: http://warnermediadiversity.com/legal-and-privacy
# 		*** 29 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 161, INDEXING CURRENT URL: http://warnermediadiversity.com/legal-and-privacy...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/legal-and-privacy', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		*** 30 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 158, INDEXING CURRENT URL: http://warnermediadiversity.com/working-us...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/working-us', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		queueing link: http://warnermediadiversity.com/working-us
# 		*** 29 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 158, INDEXING CURRENT URL: http://warnermediadiversity.com/working-us...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/working-us', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		*** 30 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 157, INDEXING CURRENT URL: http://warnermediadiversity.com/media-and-identity-materials...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/media-and-identity-materials', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		queueing link: http://warnermediadiversity.com/media-and-identity-materials
# 		*** 29 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 157, INDEXING CURRENT URL: http://warnermediadiversity.com/media-and-identity-materials...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/media-and-identity-materials', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		*** 30 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 156, INDEXING CURRENT URL: http://warnermediadiversity.com/press-contacts...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/press-contacts', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		queueing link: http://warnermediadiversity.com/press-contacts
# 		*** 29 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 156, INDEXING CURRENT URL: http://warnermediadiversity.com/press-contacts...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/press-contacts', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		*** 30 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 155, INDEXING CURRENT URL: http://warnermediadiversity.com/company/strategy...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/company/strategy', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		queueing link: http://warnermediadiversity.com/company/strategy
# 		*** 29 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 155, INDEXING CURRENT URL: http://warnermediadiversity.com/company/strategy...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/company/strategy', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		*** 30 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 154, INDEXING CURRENT URL: http://warnermediadiversity.com/company/corporate-responsibility...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/company/corporate-responsibility', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		queueing link: http://warnermediadiversity.com/company/corporate-responsibility
# 		*** 29 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 154, INDEXING CURRENT URL: http://warnermediadiversity.com/company/corporate-responsibility...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/company/corporate-responsibility', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		*** 30 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 153, INDEXING CURRENT URL: http://warnermediadiversity.com/company/business-units...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/company/business-units', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		queueing link: http://warnermediadiversity.com/company/business-units
# 		*** 29 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 153, INDEXING CURRENT URL: http://warnermediadiversity.com/company/business-units...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/company/business-units', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		*** 30 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 152, INDEXING CURRENT URL: http://warnermediadiversity.com/leadership-team...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/leadership-team', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		queueing link: http://warnermediadiversity.com/leadership-team
# 		*** 29 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 152, INDEXING CURRENT URL: http://warnermediadiversity.com/leadership-team...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/leadership-team', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		*** 30 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 151, INDEXING CURRENT URL: http://warnermediadiversity.com/about-us...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/about-us', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		queueing link: http://warnermediadiversity.com/about-us
# 		*** 29 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 151, INDEXING CURRENT URL: http://warnermediadiversity.com/about-us...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/about-us', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		*** 30 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 150, INDEXING CURRENT URL: http://warnermediadiversity.com/newsroom...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/newsroom', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		queueing link: http://warnermediadiversity.com/newsroom
# 		*** 29 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 150, INDEXING CURRENT URL: http://warnermediadiversity.com/newsroom...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/newsroom', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		*** 30 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 149, INDEXING CURRENT URL: http://warnermediadiversity.com/company...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/company', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		queueing link: http://warnermediadiversity.com/company
# 		*** 29 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 149, INDEXING CURRENT URL: http://warnermediadiversity.com/company...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='/company', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		*** 30 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 148, INDEXING CURRENT URL: http://warnermediadiversity.com#main-content...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='', params='', query='', fragment='main-content')
# 	html doc contains 30 outlinks
# 		queueing link: http://warnermediadiversity.com#main-content
# 		*** 29 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 148, INDEXING CURRENT URL: http://warnermediadiversity.com#main-content...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='warnermediadiversity.com', path='', params='', query='', fragment='main-content')
# 	html doc contains 30 outlinks
# 		*** 30 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 147, INDEXING CURRENT URL: https://trutv.app.link/HAfoCcmap4?%243p=a_custom_761352279751481230...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='trutv.app.link', path='/HAfoCcmap4', params='', query='%243p=a_custom_761352279751481230', fragment='')
# 	html doc contains 1 outlinks
# 		queueing link: {{action}}
# 		*** 0 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 147, INDEXING CURRENT URL: {{action}}...
# 	cannot index this document due to exception: unknown url type: '{{action}}'
# URLs queued: 146, INDEXING CURRENT URL: https://www.tntdrama.com/nba-on-tnt?cid=Digital-Portfolio_NBA-on-TNT-Restart_2020_WarnerMedia&amp;source=Digital-Portfolio&amp;campaign=NBA-on-TNT-Restart_2020_WarnerMedia...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='www.tntdrama.com', path='/nba-on-tnt', params='', query='cid=Digital-Portfolio_NBA-on-TNT-Restart_2020_WarnerMedia&amp;source=Digital-Portfolio&amp;campaign=NBA-on-TNT-Restart_2020_WarnerMedia', fragment='')
# 	html doc contains 797 outlinks
# 		truncating outlinks count to remaining space in queue (309)
# 		queueing link: https://www.tntdrama.com#main-content
# 		queueing link: https://www.tntdrama.com/shows
# 		queueing link: https://www.tntdrama.com/allelitewrestling
# 		queueing link: https://www.tntdrama.com/shows/animal-kingdom
# 		queueing link: https://www.tntdrama.com/shows/claws
# 		queueing link: https://www.tntdrama.com/nba-on-tnt
# 		queueing link: https://www.tntdrama.com/shaq-life
# 		queueing link: https://www.tntdrama.com/snowpiercer
# 		queueing link: https://www.tntdrama.com/movies
# 		queueing link: https://www.tntdrama.com/big-ticket-movies
# 		queueing link: https://www.tntdrama.com/watchtnt
# 		queueing link: https://www.tntdrama.com/schedule
# 		queueing link: https://www.tntdrama.com/help
# 		queueing link: https://www.tbs.com/
# 		queueing link: https://www.trutv.com/
# 		queueing link: https://www.nba.com/
# 		queueing link: https://www.tntdrama.com/backgrounds
# 		queueing link: https://www.tntdrama.com/thesteamroompodcast
# 		queueing link: https://www.facebook.com/NBAONTNT
# 		queueing link: https://twitter.com/NBAonTNT
# 		queueing link: https://www.instagram.com/nbaontnt/?hl=en
# 		queueing link: https://www.youtube.com/channel/UCU7iRrk3xfpUk0R6VdyC1Ow
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/nba-on-tnt-preview
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/season-1/the-arena-presented-by-tractor-supply-july-23-2020
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/season-1/the-arena-presented-by-tractor-supply-july-24-2020
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/season-1/the-arena-presented-by-tractor-supply-july-22-2020
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/season-1/the-arena-presented-by-tractor-supply-july-21-2020
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/season-1/the-arena-presented-by-tractor-supply-july-20-2020
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/caris-champions-maxwell-finnegan
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/jemele-hill-what-i-miss
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/nneka-ogwumike-joins-from-the-wnba-bubble
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/thank-you-vince-carter
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/raptors-president-discusses-spreading-social-awareness-in-orlando
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/caris-champions-ryan-d-wheelz
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/nfl-voices-how-josh-norman-and-demario-davis-are-making-change
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/true-fans
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/the-support-system
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/embers-in-the-dark
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/caris-champions-stacey-pierre-louis
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/united-through-ball
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/killer-mike-hawks-coach-lloyd-pierce-discuss-social-activism
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/we-are-home-by-kareem-abdul-jabbar
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/caris-champions-makur-maker
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/voting-rights-activist-stacey-abrams-joins-the-show
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/dominoes-how-the-coronavirus-changed-the-world-of-sports
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/coach-popovich-joins-from-the-nba-orlando-campus
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/caris-champions-keedron-bryant
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/jemele-hills-message-about-the-nba-and-social-justice
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/killer-mike-has-a-message-for-america
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/remembering-john-lewis
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/chris-haynes-shares-the-inside-scoop-about-the-nba-campus
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/life-inside-the-nba-campus
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/should-the-nba-be-more-transparent
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/chris-haynes-from-the-nba-orlando-campus-july-16
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/nba-bubble-lifes-funniest-videos
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/chris-haynes-from-the-nba-orlando-campus-july-14
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/chris-haynes-from-the-nba-orlando-campus-july-9
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/wizards-coach-scott-brooks-joins-the-show
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/chris-haynes-from-the-nba-orlando-campus-july-7
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/the-impact-of-meeting-john-lewis
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/jayson-tatum-talks-about-his-voter-registration-initiative
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/ejs-neat-o-stat-of-the-night-gone-fishin
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/meek-mill-has-a-message-for-the-nbas-return
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/inside-the-nba-previews-the-arena
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/ejs-neat-o-stat-of-the-night-chucks-golf-game
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/recapping-chris-pauls-nbatogether-from-orlando
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/shaq-isnt-in-chucks-all-time-top-10
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/who-he-play-for-restart-edition
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/inside-guys-reflect-on-vince-carters-legacy
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/the-inside-guys-return
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/ejs-neat-o-stat-of-the-night-trivia-night
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/ejs-neat-o-stat-of-the-night-auburn-surprises-chuck
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/ejs-neat-o-stat-of-the-night-best-of-all-star-weekend
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/ejs-neat-o-stat-of-the-night-ellen-scares-chuck
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/ejs-neat-o-stat-of-the-night-all-star-gifts
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/ejs-neat-o-stat-of-the-night-tik-tok-challenge
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/the-inside-guys-relax-with-some-goat-yoga
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/who-deserves-the-mvp-award-so-far
# 		queueing link: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/ejs-neat-o-stat-of-the-night-on-this-day-in-1989
# 		*** 230 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 224, INDEXING CURRENT URL: https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/ejs-neat-o-stat-of-the-night-on-this-day-in-1989...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='www.tntdrama.com', path='/sports/nba-on-tnt-19-20/clips/ejs-neat-o-stat-of-the-night-on-this-day-in-1989', params='', query='', fragment='')
# 	html doc contains 40 outlinks
# 		queueing link: https://tnt.app.link/iykVYBjHI1
# 		queueing link: https://www.tntdrama.com/apps
# 		queueing link: https://tbs.com/apps
# 		queueing link: https://trutv.com/apps/
# 		queueing link: https://www.facebook.com/TNTDrama
# 		queueing link: https://twitter.com/tntdrama
# 		queueing link: https://www.instagram.com/tntdrama
# 		queueing link: https://www.youtube.com/user/tntweknowdrama
# 		queueing link: https://www.tntdrama.com/privacy
# 		queueing link: https://www.tntdrama.com/terms
# 		queueing link: https://www.tntdrama.com/dvs-offerings
# 		queueing link: https://www.tntdrama.com/closed-captioning
# 		*** 28 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 235, INDEXING CURRENT URL: https://www.tntdrama.com/closed-captioning...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='www.tntdrama.com', path='/closed-captioning', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		queueing link: mailto:IPClosedCaptioning@turner.com
# 		queueing link: https://www.tntdrama.com/closed-captioning
# 		*** 28 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 236, INDEXING CURRENT URL: https://www.tntdrama.com/closed-captioning...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='www.tntdrama.com', path='/closed-captioning', params='', query='', fragment='')
# 	html doc contains 30 outlinks
# 		*** 30 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 235, INDEXING CURRENT URL: mailto:IPClosedCaptioning@turner.com...
# 	cannot index this document due to exception: <urlopen error unknown url type: mailto>
# URLs queued: 234, INDEXING CURRENT URL: https://www.tntdrama.com/dvs-offerings...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='www.tntdrama.com', path='/dvs-offerings', params='', query='', fragment='')
# 	html doc contains 29 outlinks
# 		queueing link: https://www.tntdrama.com/dvs-offerings
# 		*** 28 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 234, INDEXING CURRENT URL: https://www.tntdrama.com/dvs-offerings...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='www.tntdrama.com', path='/dvs-offerings', params='', query='', fragment='')
# 	html doc contains 29 outlinks
# 		*** 29 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 233, INDEXING CURRENT URL: https://www.tntdrama.com/terms...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='www.tntdrama.com', path='/terms', params='', query='', fragment='')
# 	html doc contains 32 outlinks
# 		queueing link: mailto:TNTcopyrightagent@turner.com
# 		queueing link: https://www.tntdrama.com/privacy.html
# 		queueing link: https://www.tntdrama.com/texting.html
# 		queueing link: https://www.tntdrama.com/terms
# 		*** 28 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 236, INDEXING CURRENT URL: https://www.tntdrama.com/terms...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='www.tntdrama.com', path='/terms', params='', query='', fragment='')
# 	html doc contains 32 outlinks
# 		*** 32 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 235, INDEXING CURRENT URL: https://www.tntdrama.com/texting.html...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='www.tntdrama.com', path='/texting.html', params='', query='', fragment='')
# 	html doc contains 33 outlinks
# 		queueing link: https://www.tntdrama.com/terms.html
# 		*** 32 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 235, INDEXING CURRENT URL: https://www.tntdrama.com/terms.html...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='www.tntdrama.com', path='/terms.html', params='', query='', fragment='')
# 	html doc contains 32 outlinks
# 		*** 32 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 234, INDEXING CURRENT URL: https://www.tntdrama.com/privacy.html...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='www.tntdrama.com', path='/privacy.html', params='', query='', fragment='')
# 	html doc contains 68 outlinks
# 		queueing link: https://www.warnermediaprivacy.com/affiliates
# 		queueing link: https://www.tntdrama.com#information-we-collect
# 		queueing link: https://www.tntdrama.com#how-we-use-the-info
# 		queueing link: https://www.tntdrama.com#information-sharing-and-disclosure
# 		queueing link: https://www.tntdrama.com#your-choices
# 		queueing link: https://www.tntdrama.com#cookies-tech-info
# 		queueing link: https://www.tntdrama.com#information-security
# 		queueing link: https://www.tntdrama.com#how-to-access-or-correct-information
# 		queueing link: https://www.tntdrama.com#childrens-privacy
# 		queueing link: https://www.tntdrama.com#international-transfer
# 		queueing link: https://www.tntdrama.com#notification-regarding-privacy-policy-updates
# 		queueing link: https://www.tntdrama.com#how-to-contact
# 		queueing link: https://www.tntdrama.com#ca-ccpa-privacy-rights-and-disclosures
# 		queueing link: mailto:wmprivacy@warnermediagroup.com
# 		queueing link: https://www.networkadvertising.org/understanding-online-advertising/what-are-my-options
# 		queueing link: https://optout.aboutads.info/?c=2&amp;lang=EN
# 		queueing link: https://youradchoices.com/appchoices
# 		queueing link: https://www.warnermediaprivacy.com/opt-out/
# 		queueing link: https://www.macromedia.com/support/documentation/en/flashplayer/help/settings_manager07.html
# 		queueing link: https://developers.google.com/analytics/devguides/collection/analyticsjs/cookie-usage
# 		queueing link: https://tools.google.com/dlpage/gaoptout?hl=en
# 		queueing link: https://www.nielsen.com/us/en/legal/privacy-statement/digital-measurement/
# 		queueing link: https://www.warnermediaprivacy.com/
# 		*** 45 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 256, INDEXING CURRENT URL: https://www.warnermediaprivacy.com/...
# 	cannot index this document due to exception: HTTP Error 403: Forbidden
# URLs queued: 255, INDEXING CURRENT URL: https://www.nielsen.com/us/en/legal/privacy-statement/digital-measurement/...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='www.nielsen.com', path='/us/en/legal/privacy-statement/digital-measurement/', params='', query='', fragment='')
# 	html doc contains 3 outlinks
# 		queueing link: "><img alt=
# 		queueing link: https://www.nielsen.com/us/en/client-login
# 		queueing link: https://www.nielsen.com/eu/en
# 		*** 0 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 257, INDEXING CURRENT URL: https://www.nielsen.com/eu/en...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='www.nielsen.com', path='/eu/en', params='', query='', fragment='')
# 	html doc contains 3 outlinks
# 		queueing link: https://www.nielsen.com/eu/en/client-login
# 		queueing link: https://www.nielsen.com/eu/en
# 		*** 1 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 258, INDEXING CURRENT URL: https://www.nielsen.com/eu/en...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='www.nielsen.com', path='/eu/en', params='', query='', fragment='')
# 	html doc contains 3 outlinks
# 		*** 3 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 257, INDEXING CURRENT URL: https://www.nielsen.com/eu/en/client-login...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='www.nielsen.com', path='/eu/en/client-login', params='', query='', fragment='')
# 	html doc contains 3 outlinks
# 		queueing link: https://www.nielsen.com/eu/en/client-login
# 		*** 2 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 257, INDEXING CURRENT URL: https://www.nielsen.com/eu/en/client-login...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='www.nielsen.com', path='/eu/en/client-login', params='', query='', fragment='')
# 	html doc contains 3 outlinks
# 		*** 3 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 256, INDEXING CURRENT URL: https://www.nielsen.com/us/en/client-login...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='www.nielsen.com', path='/us/en/client-login', params='', query='', fragment='')
# 	html doc contains 3 outlinks
# 		queueing link: https://www.nielsen.com/us/en/client-login
# 		*** 2 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 256, INDEXING CURRENT URL: https://www.nielsen.com/us/en/client-login...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='www.nielsen.com', path='/us/en/client-login', params='', query='', fragment='')
# 	html doc contains 3 outlinks
# 		*** 3 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 255, INDEXING CURRENT URL: "><img alt=...
# 	cannot index this document due to exception: unknown url type: '"><img alt='
# URLs queued: 254, INDEXING CURRENT URL: https://tools.google.com/dlpage/gaoptout?hl=en...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='tools.google.com', path='/dlpage/gaoptout', params='', query='hl=en', fragment='')
# 	html doc contains 2 outlinks
# 		queueing link: http://www.google.com/support/bin/answer.py?answer=23852&amp;hl=en
# 		queueing link: https://www.google.com
# 		*** 0 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 255, INDEXING CURRENT URL: https://www.google.com...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='www.google.com', path='', params='', query='', fragment='')
# 	html doc contains 17 outlinks
# 		queueing link: https://www.google.com/imghp?hl=en&amp;tab=wi
# 		queueing link: https://maps.google.com/maps?hl=en&amp;tab=wl
# 		queueing link: https://play.google.com/?hl=en&amp;tab=w8
# 		queueing link: https://www.youtube.com/?gl=US&amp;tab=w1
# 		queueing link: https://news.google.com/nwshp?hl=en&amp;tab=wn
# 		queueing link: https://mail.google.com/mail/?tab=wm
# 		queueing link: https://drive.google.com/?tab=wo
# 		queueing link: https://www.google.com/intl/en/about/products?tab=wh
# 		queueing link: http://www.google.com/history/optout?hl=en
# 		queueing link: https://www.google.com/preferences?hl=en
# 		queueing link: https://accounts.google.com/ServiceLogin?hl=en&amp;passive=true&amp;continue=https://www.google.com/
# 		queueing link: https://www.google.com/advanced_search?hl=en&amp;authuser=0
# 		queueing link: https://www.google.com/intl/en/ads/
# 		queueing link: https://www.google.com/services/
# 		queueing link: https://www.google.com/intl/en/about.html
# 		queueing link: https://www.google.com/intl/en/policies/privacy/
# 		queueing link: https://www.google.com/intl/en/policies/terms/
# 		*** 0 of the remaining outlinks are either queued to be or have already been crawled ***
# 	INDEXING COMPLETE
# URLs queued: 271, INDEXING CURRENT URL: https://www.google.com/intl/en/policies/terms/...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='www.google.com', path='/intl/en/policies/terms/', params='', query='', fragment='')
# 	cannot index this document since it does not have an html BODY tag
# URLs queued: 270, INDEXING CURRENT URL: https://www.google.com/intl/en/policies/privacy/...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='www.google.com', path='/intl/en/policies/privacy/', params='', query='', fragment='')
# 	cannot index this document since it does not have an html BODY tag
# URLs queued: 269, INDEXING CURRENT URL: https://www.google.com/intl/en/about.html...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='www.google.com', path='/intl/en/about.html', params='', query='', fragment='')
# 	html doc contains 103 outlinks
# 		queueing link: https://www.google.com#content
# 		queueing link: ./
# 		queueing link: https://www.google.com/products/
# 		queueing link: ./products/
# 		queueing link: https://www.google.com/commitments/
# 		queueing link: ./commitments/
# 		queueing link: https://www.google.com/stories/
# 		queueing link: ./stories/
# 		queueing link: https://www.blog.google/?utm_source=about.google&amp;utm_medium=referral&amp;utm_campaign=nav-news
# 		queueing link: https://www.blog.google/?utm_source=about.google&amp;utm_medium=referral&amp;utm_campaign=nav-blog
# 		queueing link: https://www.blog.google/?utm_source=about.google&amp;utm_medium=referral&amp;utm_campaign=nav-the-keyword
# 		queueing link: https://www.google.com/commitments/racialequity/
# 		queueing link: {[::feed.url]}
# 		queueing link: products
# 		queueing link: commitments
# 		queueing link: stories
# 		queueing link: https://careers.google.com/
# 		queueing link: locations/
# 		queueing link: our-story
# 		queueing link: https://abc.xyz/investor/founders-letters/2004/ipo-letter.html#_ga=2.165626872.610004439.1532311821-929489725.1521479135
# 		queueing link: https://www.google.com/doodles/{[::doodle.name]}
# 		queueing link: https://www.google.com/doodles/{[::doodleCtrl.doodleHistory[0].name]}
# 		queueing link: https://www.google.com/doodles
# 		queueing link: https://instagram.com/google/
# 		queueing link: https://www.youtube.com/user/Google
# 		queueing link: https://twitter.com/google
# 		queueing link: https://www.facebook.com/Google
# 		queueing link: https://www.linkedin.com/company/google
# 		queueing link: https://www.google.com/contact/
# 		queueing link: https://abc.xyz/investor/
# 		queueing link: https://www.google.com/locations/
# 		queueing link: ./locations/
# 		queueing link: https://www.blog.google/
# 		queueing link: https://www.thinkwithgoogle.com/
# 		queueing link: https://www.blog.google/press/
# 		queueing link: https://www.google.com/permissions/
# 		queueing link: https://services.google.com/fb/forms/speakerrequest/
# 		queueing link: https://www.google.com/about/appsecurity/
# 		queueing link: https://www.google.com/about/software-principles.html
# ...
# URLs queued: 57, INDEXING CURRENT URL: https://cnn.com/style/arts...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/style/arts', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 56, INDEXING CURRENT URL: https://cnn.com/specials/tech/innovative-cities...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/specials/tech/innovative-cities', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 55, INDEXING CURRENT URL: https://cnn.com/specials/tech/work-transformed...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/specials/tech/work-transformed', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 54, INDEXING CURRENT URL: https://cnn.com/specials/tech/upstarts...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/specials/tech/upstarts', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 53, INDEXING CURRENT URL: https://cnn.com/specials/tech/mission-ahead...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/specials/tech/mission-ahead', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 52, INDEXING CURRENT URL: https://cnn.com/specials/tech/foreseeable-future...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/specials/tech/foreseeable-future', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 51, INDEXING CURRENT URL: https://cnn.com/specials/tech/gadget...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/specials/tech/gadget', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 50, INDEXING CURRENT URL: https://cnn.com/specials/tech/innovate...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/specials/tech/innovate', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 49, INDEXING CURRENT URL: https://cnn.com/entertainment/culture...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/entertainment/culture', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 48, INDEXING CURRENT URL: https://cnn.com/entertainment/tv-shows...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/entertainment/tv-shows', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 47, INDEXING CURRENT URL: https://cnn.com/entertainment/movies...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/entertainment/movies', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 46, INDEXING CURRENT URL: https://cnn.com/entertainment/celebrities...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/entertainment/celebrities', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 45, INDEXING CURRENT URL: https://cnn.com/specials/health/vital-signs...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/specials/health/vital-signs', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 44, INDEXING CURRENT URL: https://cnn.com/specials/health/parenting...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/specials/health/parenting', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 43, INDEXING CURRENT URL: https://cnn.com/specials/health/wellness...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/specials/health/wellness', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 42, INDEXING CURRENT URL: https://cnn.com/specials/health/fitness-excercise...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/specials/health/fitness-excercise', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 41, INDEXING CURRENT URL: https://cnn.com/specials/health/food-diet...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/specials/health/food-diet', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 40, INDEXING CURRENT URL: https://cnn.com/specials/opinion/opinion-social-issues...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/specials/opinion/opinion-social-issues', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 39, INDEXING CURRENT URL: https://cnn.com/specials/opinion/opinion-politics...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/specials/opinion/opinion-politics', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 38, INDEXING CURRENT URL: https://cnn.com/business/videos...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/business/videos', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 37, INDEXING CURRENT URL: https://cnn.com/business/perspectives...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/business/perspectives', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 36, INDEXING CURRENT URL: https://cnn.com/business/success...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/business/success', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 35, INDEXING CURRENT URL: https://cnn.com/business/media...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/business/media', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 34, INDEXING CURRENT URL: https://cnn.com/business/tech...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/business/tech', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 33, INDEXING CURRENT URL: https://money.cnn.com/data/markets/...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='money.cnn.com', path='/data/markets/', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 32, INDEXING CURRENT URL: https://cnn.com/specials/politics/fact-check-politics...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/specials/politics/fact-check-politics', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 31, INDEXING CURRENT URL: https://cnn.com/specials/politics/congress...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/specials/politics/congress', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 30, INDEXING CURRENT URL: https://cnn.com/specials/politics/supreme-court-nine...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/specials/politics/supreme-court-nine', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 29, INDEXING CURRENT URL: https://cnn.com/specials/politics/president-donald-trump-45...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/specials/politics/president-donald-trump-45', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 28, INDEXING CURRENT URL: https://cnn.com/election/2020...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/election/2020', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 27, INDEXING CURRENT URL: https://cnn.com/uk...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/uk', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 26, INDEXING CURRENT URL: https://cnn.com/middle-east...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/middle-east', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 25, INDEXING CURRENT URL: https://cnn.com/india...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/india', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 24, INDEXING CURRENT URL: https://cnn.com/europe...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/europe', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 23, INDEXING CURRENT URL: https://cnn.com/china...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/china', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 22, INDEXING CURRENT URL: https://cnn.com/australia...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/australia', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 21, INDEXING CURRENT URL: https://cnn.com/asia...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/asia', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 20, INDEXING CURRENT URL: https://cnn.com/americas...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/americas', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 19, INDEXING CURRENT URL: https://cnn.com/africa...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/africa', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 18, INDEXING CURRENT URL: https://cnn.com/specials/space-science...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/specials/space-science', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 17, INDEXING CURRENT URL: https://cnn.com/specials/us/extreme-weather...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/specials/us/extreme-weather', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 16, INDEXING CURRENT URL: https://cnn.com/specials/us/energy-and-environment...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/specials/us/energy-and-environment', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 15, INDEXING CURRENT URL: https://cnn.com/specials/us/crime-and-justice...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/specials/us/crime-and-justice', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 14, INDEXING CURRENT URL: https://cnnespanol.cnn.com?hpt=header_edition-picker...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnnespanol.cnn.com', path='', params='', query='hpt=header_edition-picker', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 13, INDEXING CURRENT URL: https://arabic.cnn.com?hpt=header_edition-picker...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='arabic.cnn.com', path='', params='', query='hpt=header_edition-picker', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 12, INDEXING CURRENT URL: https://edition.cnn.com?hpt=header_edition-picker...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='edition.cnn.com', path='', params='', query='hpt=header_edition-picker', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 11, INDEXING CURRENT URL: https://us.cnn.com?hpt=header_edition-picker...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='us.cnn.com', path='', params='', query='hpt=header_edition-picker', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 10, INDEXING CURRENT URL: https://cnn.com/videos...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/videos', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 9, INDEXING CURRENT URL: http://bleacherreport.com...
# 	parsed_doc_url: ParseResult(scheme='http', netloc='bleacherreport.com', path='', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 8, INDEXING CURRENT URL: https://cnn.com/travel...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/travel', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 7, INDEXING CURRENT URL: https://cnn.com/style...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/style', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 6, INDEXING CURRENT URL: https://cnn.com/entertainment...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/entertainment', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 5, INDEXING CURRENT URL: https://cnn.com/health...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/health', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 4, INDEXING CURRENT URL: https://cnn.com/opinions...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/opinions', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 3, INDEXING CURRENT URL: https://cnn.com/business...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/business', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 2, INDEXING CURRENT URL: https://cnn.com/politics...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/politics', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 1, INDEXING CURRENT URL: https://cnn.com/world...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/world', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
# URLs queued: 0, INDEXING CURRENT URL: https://cnn.com/us...
# 	parsed_doc_url: ParseResult(scheme='https', netloc='cnn.com', path='/us', params='', query='', fragment='')
# 	skipping outlinks scan: outlinks queue is full
# 	INDEXING COMPLETE
#
#
# Indexing Complete (started at 17:39), writing to storage (sqlite database): 17:53
# Documents: 498
# Terms: 73388
# Tokens: 6631079
# End Time: 18:02
# Enter URL to crawl (must be in the form http://www.domain.com):
# Are you sure you want to QUIT? (press ENTER again to confirm):

# %% [markdown]
# # Part 2: Search Engine (using the inverted index sqlite database created above)

# %%
from unit5.search_engine import SearchEngine

# %%
srch_engine = SearchEngine("unit7/webcrawler.db")
srch_engine.run()

# we're done
disp("")
disp("")
disp("That's all, folks.  Thanks for playing!  BYE BYE.")
# Out:
# Enter the search terms, each separated by a space (or just press ENTER to QUIT):  election candidates biden trump
# raw search terms:
# 	'election candidates biden trump'
#
# tokenized/processed search terms:
# 	['elect', 'candid', 'biden', 'trump']
# |   TermId | Term   |   N |   df_t |   idf_t |
# |---------:|:-------|----:|-------:|--------:|
# |      301 | elect  | 498 |    103 | 1.57587 |
# |      304 | trump  | 498 |    105 | 1.55664 |
# |    19167 | biden  | 498 |     21 | 3.16608 |
# |    19168 | candid | 498 |     39 | 2.54704 |
# ### SEARCH RESULTS: The following documents contain all of the above search terms (results ordered by cosine similarity)
# 14 documents found:
# |   DocId | DocumentName                                                |    norm |   cosine_similarity | tfidf                                                                                                                 |
# |--------:|:------------------------------------------------------------|--------:|--------------------:|:----------------------------------------------------------------------------------------------------------------------|
# |     470 | https://cnn.com/election/2020                               | 1914.25 |          0.136607   | {'elect': 724.9007008457079, 'trump': 43.58591235227963, 'biden': 18.996465835807378, 'candid': 73.86411449595519}    |
# |     466 | https://cnn.com/specials/politics/fact-check-politics       | 4034.86 |          0.0677842  | {'elect': 110.3109762156512, 'trump': 582.1832578483064, 'biden': 275.44875461920697, 'candid': 40.752614894320104}   |
# |     459 | https://cnn.com/specials/opinion/opinion-politics           | 7647.48 |          0.0619158  | {'elect': 130.79730036998643, 'trump': 1116.1106841637318, 'biden': 338.77030740523156, 'candid': 101.88153723580027} |
# |     469 | https://cnn.com/specials/politics/president-donald-trump-45 | 4022.27 |          0.0568087  | {'elect': 119.7662027484213, 'trump': 544.8239044034954, 'biden': 88.65017390043444, 'candid': 7.641115292685019}     |
# |     494 | https://cnn.com/opinions                                    | 6210.46 |          0.043153   | {'elect': 132.37317145878143, 'trump': 610.2027729319148, 'biden': 139.3074161292541, 'candid': 40.752614894320104}   |
# |     467 | https://cnn.com/specials/politics/congress                  | 5487.35 |          0.0356274  | {'elect': 157.58710887950173, 'trump': 314.44122482716017, 'biden': 240.62190058689347, 'candid': 33.11149960163508}  |
# |     498 | https://cnn.com/us                                          | 3846.46 |          0.0231381  | {'elect': 81.94529661734089, 'trump': 144.76749459864305, 'biden': 72.81978570392829, 'candid': 25.470384308950067}   |
# |     483 | https://cnn.com/specials/us/crime-and-justice               | 8526.11 |          0.0224018  | {'elect': 105.58336294926615, 'trump': 456.09543997206896, 'biden': 44.32508695021722, 'candid': 20.376307447160052}  |
# |     400 | https://cnn.com/specials/world/cnn-climate                  | 3972.87 |          0.0142215  | {'elect': 100.8557496828811, 'trump': 20.23631644927268, 'biden': 101.31448445763935, 'candid': 10.188153723580026}   |
# |     482 | https://cnn.com/specials/us/energy-and-environment          | 8606.19 |          0.0124329  | {'elect': 91.400523150111, 'trump': 118.30461924190185, 'biden': 234.289745308291, 'candid': 15.282230585370039}      |
# |     239 | https://news.google.com/nwshp?hl=en&amp;tab=wn              | 7468.79 |          0.00783259 | {'elect': 12.606968710360137, 'trump': 105.8515014269648, 'biden': 91.81625153973566, 'candid': 30.564461170740078}   |
# |     164 | https://news.google.com/nwshp?hl=en&amp;tab=un              | 7494.41 |          0.00733881 | {'elect': 12.606968710360137, 'trump': 94.9550233388949, 'biden': 91.81625153973566, 'candid': 30.564461170740078}    |
# |     165 | https://play.google.com/?hl=en&amp;tab=u8                   | 8148.36 |          0.00202495 | {'elect': 3.1517421775900343, 'trump': 40.47263289854536, 'biden': 9.498232917903689, 'candid': 5.094076861790013}    |
# |     241 | https://play.google.com/?hl=en&amp;tab=w8                   | 8149.16 |          0.00202475 | {'elect': 3.1517421775900343, 'trump': 40.47263289854536, 'biden': 9.498232917903689, 'candid': 5.094076861790013}    |
# Enter the search terms, each separated by a space (or just press ENTER to QUIT):  coronavirus sports
# raw search terms:
# 	'coronavirus sports'
#
# tokenized/processed search terms:
# 	['coronaviru', 'sport']
# |   TermId | Term       |   N |   df_t |    idf_t |
# |---------:|:-----------|----:|-------:|---------:|
# |      149 | sport      | 498 |    222 | 0.807923 |
# |     1744 | coronaviru | 498 |    119 | 1.43148  |
# ### SEARCH RESULTS: The following documents contain all of the above search terms (results ordered by cosine similarity)
# 112 documents found, displaying the first 20...
# |   DocId | DocumentName                                                                                                          |    norm |   cosine_similarity | tfidf                                                           |
# |--------:|:----------------------------------------------------------------------------------------------------------------------|--------:|--------------------:|:----------------------------------------------------------------|
# |     308 | https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/dominoes-how-the-coronavirus-changed-the-world-of-sports       | 661.773 |           0.0897543 | {'sport': 62.210047526732765, 'coronaviru': 10.020336087391865} |
# |     305 | https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/jemele-hills-message-about-the-nba-and-social-justice          | 661.884 |           0.0811927 | {'sport': 58.978356746123275, 'coronaviru': 4.29442975173937}   |
# |     354 | https://www.warnermediagroup.com/what-warnermedia-doing-response-covid-19                                             | 515.667 |           0.0809036 | {'sport': 7.271304256371362, 'coronaviru': 71.57382919565617}   |
# |     275 | https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/who-deserves-the-mvp-award-so-far                              | 666.918 |           0.0773991 | {'sport': 56.55458866066615, 'coronaviru': 4.29442975173937}    |
# |     280 | https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/ejs-neat-o-stat-of-the-night-best-of-all-star-weekend          | 667.516 |           0.0773297 | {'sport': 56.55458866066615, 'coronaviru': 4.29442975173937}    |
# |     276 | https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/the-inside-guys-relax-with-some-goat-yoga                      | 667.622 |           0.0773174 | {'sport': 56.55458866066615, 'coronaviru': 4.29442975173937}    |
# |     281 | https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/ejs-neat-o-stat-of-the-night-auburn-surprises-chuck            | 667.905 |           0.0772846 | {'sport': 56.55458866066615, 'coronaviru': 4.29442975173937}    |
# |     279 | https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/ejs-neat-o-stat-of-the-night-ellen-scares-chuck                | 668.096 |           0.0772626 | {'sport': 56.55458866066615, 'coronaviru': 4.29442975173937}    |
# |     282 | https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/ejs-neat-o-stat-of-the-night-trivia-night                      | 668.317 |           0.077237  | {'sport': 56.55458866066615, 'coronaviru': 4.29442975173937}    |
# |     277 | https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/ejs-neat-o-stat-of-the-night-tik-tok-challenge                 | 668.793 |           0.077182  | {'sport': 56.55458866066615, 'coronaviru': 4.29442975173937}    |
# |     313 | https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/united-through-ball                                            | 659.963 |           0.0771433 | {'sport': 55.74666596551378, 'coronaviru': 4.29442975173937}    |
# |      44 | https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/ejs-neat-o-stat-of-the-night-on-this-day-in-1989               | 669.259 |           0.0771283 | {'sport': 56.55458866066615, 'coronaviru': 4.29442975173937}    |
# |     278 | https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/ejs-neat-o-stat-of-the-night-all-star-gifts                    | 669.288 |           0.077125  | {'sport': 56.55458866066615, 'coronaviru': 4.29442975173937}    |
# |     293 | https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/the-impact-of-meeting-john-lewis                               | 660.239 |           0.077111  | {'sport': 55.74666596551378, 'coronaviru': 4.29442975173937}    |
# |     303 | https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/remembering-john-lewis                                         | 660.242 |           0.0771106 | {'sport': 55.74666596551378, 'coronaviru': 4.29442975173937}    |
# |     288 | https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/ejs-neat-o-stat-of-the-night-chucks-golf-game                  | 660.264 |           0.077108  | {'sport': 55.74666596551378, 'coronaviru': 4.29442975173937}    |
# |     283 | https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/the-inside-guys-return                                         | 660.353 |           0.0770977 | {'sport': 55.74666596551378, 'coronaviru': 4.29442975173937}    |
# |     318 | https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/nfl-voices-how-josh-norman-and-demario-davis-are-making-change | 660.364 |           0.0770964 | {'sport': 55.74666596551378, 'coronaviru': 4.29442975173937}    |
# |     311 | https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/we-are-home-by-kareem-abdul-jabbar                             | 660.41  |           0.0770911 | {'sport': 55.74666596551378, 'coronaviru': 4.29442975173937}    |
# |     287 | https://www.tntdrama.com/sports/nba-on-tnt-19-20/clips/recapping-chris-pauls-nbatogether-from-orlando                 | 660.49  |           0.0770817 | {'sport': 55.74666596551378, 'coronaviru': 4.29442975173937}    |
# Enter the search terms, each separated by a space (or just press ENTER to QUIT):  mars perseverance spacex
# raw search terms:
# 	'mars perseverance spacex'
#
# tokenized/processed search terms:
# 	['mar', 'persever', 'spacex']
# |   TermId | Term     |   N |   df_t |   idf_t |
# |---------:|:---------|----:|-------:|--------:|
# |    13153 | mar      | 498 |     18 | 3.32023 |
# |    19535 | spacex   | 498 |     13 | 3.64565 |
# |    21318 | persever | 498 |      5 | 4.60116 |
# ### SEARCH RESULTS: The following documents contain all of the above search terms (results ordered by cosine similarity)
# 1 documents found:
# |   DocId | DocumentName                           |   norm |   cosine_similarity | tfidf                                                                                   |
# |--------:|:---------------------------------------|-------:|--------------------:|:----------------------------------------------------------------------------------------|
# |     480 | https://cnn.com/specials/space-science | 8703.5 |           0.0382755 | {'mar': 1089.0348886741442, 'spacex': 565.0758615322829, 'persever': 432.5092434715119} |
# Enter the search terms, each separated by a space (or just press ENTER to QUIT):
# Are you sure you want to QUIT? (press ENTER again to confirm):
# That's all, folks.  Thanks for playing!  BYE BYE.

# %% [markdown]
# <p><br><br>
#
# # Conclusion
# This document was produced as a (IPython) Jupyter Notebook. ("Project Jupyter", 2020)

# %% [markdown]
# <p><br><br>
#
# ### References

# %% [markdown]
# Manning, C., Raghavan, P., & Schütze, H. (2008). Introduction to Information Retrieval [Ebook]. Cambridge University Press. Retrieved from http://nlp.stanford.edu/IR-book/pdf/irbookprint.pdf

# %% [markdown]
# Project Jupyter. (2020). Retrieved from https://jupyter.org/documentation
